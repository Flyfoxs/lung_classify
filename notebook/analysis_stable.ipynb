# %%
import os

def adjust_wkdir(cut_folder='notebook'):
    abspath = os.path.abspath('.')
    wk_dir = abspath.replace(cut_folder,'')
    os.chdir(wk_dir)
    return wk_dir


adjust_wkdir()
# Out:
# '/share/felix/pj/lung_classify/'

# %%
import logging
logging.basicConfig(level=logging.INFO)

import pandas as pd
import os
from task_distribute.locker import task_locker
from file_cache.cache import file_cache, logger, timed

#from tqdm._tqdm_notebook import tqdm_notebook as  tqdm

from tqdm import tqdm, tqdm_notebook
from glob import glob
import itertools
import numpy as np
from easydict import EasyDict as edict

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# INFO:root:Start the program at:amax3, 10.10.20.103, with:Load module
# yes

# %%
df = pd.read_csv('./input/train_bboxes.csv')
gp = df.groupby('filename').x.count().sort_index()

count_img = len(glob('./input/train/*.jpg'))
print(df.shape, gp.shape, count_img)
df.head(3)
# Out:
# (7167, 5) (4509,) 20013
#    filename      x      y  width  height
# 0         6  287.0  673.0  188.0   220.0
# 1         8  651.0  476.0  250.0   344.0
# 2        18  220.0  414.0  142.0   120.0

# %%
df = pd.read_csv('./input/train_bboxes.csv')
df = df.drop_duplicates('filename')
df['fold'] = df.filename%5
df.fold.value_counts()
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# 1    935
# 2    925
# 4    884
# 0    884
# 3    881
# Name: fold, dtype: int64

# %%
df = pd.read_csv('./input/train.csv', names=['filename', 'label'])
#df.head()

df.label.value_counts()
# Out:
# 0    15504
# 2     2450
# 1     1960
# 3       89
# 4       10
# Name: label, dtype: int64

# %%
import matplotlib.pyplot as plt
from glob import glob

file_list = list(glob('./input/train/*.jpg'))[:8]
print(file_list)
img_list = [plt.imread (file) for file in file_list]


from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

fig = plt.figure(figsize=(20., 50.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(2,4),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 share_all=True,
                 )

for ax, im in zip(grid, img_list):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)
plt.show()
# Out:
# ['./input/train/8755.jpg', './input/train/158.jpg', './input/train/1570.jpg', './input/train/4223.jpg', './input/train/312.jpg', './input/train/9240.jpg', './input/train/9708.jpg', './input/train/19325.jpg']

# %%
import os
import numpy as np
import json
import cv2
import random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from detectron2.structures import BoxMode
from functools import lru_cache

@lru_cache()
def get_anotation_dicts(fold=None, box_cnt=None):
    cls = pd.read_csv('./input/train.csv', names=['filename', 'label'])#.sample(100)
    cls['fold'] = cls.filename%5
    if fold:
        cls = cls.loc[cls.fold.isin(fold)]
    if box_cnt:
        df = pd.read_csv('./input/train_bboxes.csv')
        tmp = df.groupby('filename').filename.count().sort_values()
        tmp = tmp.loc[tmp==box_cnt]
        cls = cls.loc[cls.filename.isin(tmp.index)]
    
    bbox= pd.read_csv('./input/train_bboxes.csv')

    dataset_dicts = []
    for idx, v in tqdm(cls.iterrows(), position=0, desc=f'gen_annotaion_{str(fold)}', total=len(cls)):
        record = {}
        filename = v["filename"]
        #filename = os.path.join(img_dir, v["filename"])
        height, width = cv2.imread(f'input/train/{filename}.jpg').shape[:2]
        #print(height, width)
        
        record["file_name"] = f'input/train/{filename}.jpg'
        record["image_id"] = idx
        record["height"] = height
        record["width"] = width
      

        objs = []
        for _, anno in bbox.loc[bbox.filename==v["filename"]].iterrows():
#             assert not anno["region_attributes"]
#             anno = anno["shape_attributes"]
#             px = anno["all_points_x"]
#             py = anno["all_points_y"]
#             poly = [(x + 0.5, y + 0.5) for x, y in zip(px, py)]
#             poly = [p for x in poly for p in x]
           
            if len(anno)>0 :
                #print(anno)
                obj = {
                    "bbox": [anno.x, anno.y, anno.width, anno.height],
                    "bbox_mode": BoxMode.XYWH_ABS,
                    "category_id": 0,
                    "thing_classes": 'bz',
                    "iscrowd": 0
                }
                objs.append(obj)
        if objs:
            record["annotations"] = objs
            dataset_dicts.append(record)
    print(f'dataset_dicts={len(dataset_dicts)}')
    return dataset_dicts

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
for d, folds in zip(["train", "val"], [(0,1,2,3), (4,)]):
    if "lung_" + d not in DatasetCatalog.list():
        DatasetCatalog.register("lung_" + d, lambda d=d: get_anotation_dicts(folds))
        MetadataCatalog.get("lung_" + d).set(thing_classes=["bz"])
metadata = MetadataCatalog.get("lung_train")

dataset_dicts = get_anotation_dicts((0,1,2,3))
# Out:
# gen_annotaion_(0, 1, 2, 3): 100%|██████████| 16011/16011 [06:30<00:00, 41.00it/s]
# dataset_dicts=3625

# %%
metadata
# Out:
# Metadata(name='lung_train', thing_classes=['bz'])

# %%
# Sample image, and show it

img_list =[]
for d in dataset_dicts[:8]:
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=0.3)
    vis = visualizer.draw_dataset_dict(d)
    #
    img_list.append(vis.get_image()[:, :, ::-1])

fig = plt.figure(figsize=(20., 50.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(2,4),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 share_all=True,
                 )

for ax, im in zip(grid, img_list):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)
plt.show()

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/retinanet_R_101_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("lung_train",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/retinanet_R_101_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 3000    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ballon)

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# WARNING:fvcore.common.config:Loading config /share/felix/pj/detectron2/detectron2/model_zoo/configs/COCO-Detection/../Base-RetinaNet.yaml with yaml.unsafe_load. Your machine may be at risk if the file contains malicious content.
# INFO:detectron2.engine.defaults:Model:
# RetinaNet(
#   (backbone): FPN(
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelP6P7(
#       (p6): Conv2d(2048, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (p7): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (head): RetinaNetHead(
#     (cls_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (bbox_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (cls_score): Conv2d(256, 720, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bbox_pred): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (anchor_generator): DefaultAnchorGenerator(
#     (cell_anchors): BufferList()
#   )
# )
# gen_annotaion_(4,): 100%|██████████| 4002/4002 [01:10<00:00, 57.03it/s]
# INFO:detectron2.data.build:Removed 0 images with no usable annotations. 884 images left.
# INFO:detectron2.data.build:Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |     bz     | 1414         |
# |            |              |
# INFO:detectron2.data.detection_utils:TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# INFO:detectron2.data.build:Using training sampler TrainingSampler
# dataset_dicts=884
# INFO:fvcore.common.checkpoint:Loading checkpoint from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/retinanet_R_101_FPN_3x/138363263/model_final_59f53c.pkl
# INFO:fvcore.common.file_io:URL https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/retinanet_R_101_FPN_3x/138363263/model_final_59f53c.pkl cached in /home/felix/.torch/fvcore_cache/detectron2/COCO-Detection/retinanet_R_101_FPN_3x/138363263/model_final_59f53c.pkl
# INFO:fvcore.common.checkpoint:Reading a file from 'Detectron2 Model Zoo'
# INFO:detectron2.engine.train_loop:Starting training from iteration 0
# INFO:detectron2.utils.events:eta: 0:10:01  iter: 19  total_loss: 1.906  loss_cls: 1.404  loss_box_reg: 0.470  time: 0.2024  data_time: 0.0147  lr: 0.000005  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:35  iter: 39  total_loss: 1.709  loss_cls: 1.229  loss_box_reg: 0.457  time: 0.1989  data_time: 0.0070  lr: 0.000010  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:28  iter: 59  total_loss: 1.258  loss_cls: 0.769  loss_box_reg: 0.468  time: 0.1974  data_time: 0.0054  lr: 0.000015  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:27  iter: 79  total_loss: 0.913  loss_cls: 0.538  loss_box_reg: 0.364  time: 0.1989  data_time: 0.0049  lr: 0.000020  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:21  iter: 99  total_loss: 0.993  loss_cls: 0.590  loss_box_reg: 0.405  time: 0.1976  data_time: 0.0052  lr: 0.000025  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:19  iter: 119  total_loss: 0.882  loss_cls: 0.529  loss_box_reg: 0.355  time: 0.1991  data_time: 0.0060  lr: 0.000030  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:15  iter: 139  total_loss: 0.913  loss_cls: 0.530  loss_box_reg: 0.369  time: 0.1995  data_time: 0.0053  lr: 0.000035  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:10  iter: 159  total_loss: 0.766  loss_cls: 0.416  loss_box_reg: 0.351  time: 0.1988  data_time: 0.0054  lr: 0.000040  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:07  iter: 179  total_loss: 0.811  loss_cls: 0.454  loss_box_reg: 0.347  time: 0.1990  data_time: 0.0052  lr: 0.000045  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:09:02  iter: 199  total_loss: 0.804  loss_cls: 0.454  loss_box_reg: 0.368  time: 0.1987  data_time: 0.0050  lr: 0.000050  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:59  iter: 219  total_loss: 0.784  loss_cls: 0.437  loss_box_reg: 0.329  time: 0.1988  data_time: 0.0045  lr: 0.000055  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:56  iter: 239  total_loss: 0.801  loss_cls: 0.432  loss_box_reg: 0.343  time: 0.1995  data_time: 0.0049  lr: 0.000060  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:52  iter: 259  total_loss: 0.777  loss_cls: 0.424  loss_box_reg: 0.336  time: 0.1995  data_time: 0.0057  lr: 0.000065  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:48  iter: 279  total_loss: 0.786  loss_cls: 0.443  loss_box_reg: 0.333  time: 0.1994  data_time: 0.0062  lr: 0.000070  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:44  iter: 299  total_loss: 0.666  loss_cls: 0.353  loss_box_reg: 0.329  time: 0.1988  data_time: 0.0055  lr: 0.000075  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:40  iter: 319  total_loss: 0.740  loss_cls: 0.411  loss_box_reg: 0.306  time: 0.1985  data_time: 0.0053  lr: 0.000080  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:36  iter: 339  total_loss: 0.747  loss_cls: 0.415  loss_box_reg: 0.331  time: 0.1985  data_time: 0.0052  lr: 0.000085  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:33  iter: 359  total_loss: 0.683  loss_cls: 0.392  loss_box_reg: 0.316  time: 0.1990  data_time: 0.0051  lr: 0.000090  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:29  iter: 379  total_loss: 0.672  loss_cls: 0.376  loss_box_reg: 0.296  time: 0.1993  data_time: 0.0051  lr: 0.000095  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:25  iter: 399  total_loss: 0.659  loss_cls: 0.354  loss_box_reg: 0.314  time: 0.1993  data_time: 0.0048  lr: 0.000100  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:21  iter: 419  total_loss: 0.630  loss_cls: 0.341  loss_box_reg: 0.273  time: 0.1994  data_time: 0.0052  lr: 0.000105  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:17  iter: 439  total_loss: 0.680  loss_cls: 0.376  loss_box_reg: 0.296  time: 0.1991  data_time: 0.0051  lr: 0.000110  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:13  iter: 459  total_loss: 0.656  loss_cls: 0.345  loss_box_reg: 0.286  time: 0.1991  data_time: 0.0056  lr: 0.000115  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:11  iter: 479  total_loss: 0.581  loss_cls: 0.327  loss_box_reg: 0.287  time: 0.1995  data_time: 0.0060  lr: 0.000120  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:07  iter: 499  total_loss: 0.626  loss_cls: 0.328  loss_box_reg: 0.307  time: 0.1996  data_time: 0.0054  lr: 0.000125  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:05  iter: 519  total_loss: 0.623  loss_cls: 0.340  loss_box_reg: 0.272  time: 0.2001  data_time: 0.0050  lr: 0.000130  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:08:01  iter: 539  total_loss: 0.697  loss_cls: 0.398  loss_box_reg: 0.288  time: 0.2002  data_time: 0.0051  lr: 0.000135  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:57  iter: 559  total_loss: 0.683  loss_cls: 0.362  loss_box_reg: 0.317  time: 0.2003  data_time: 0.0054  lr: 0.000140  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:53  iter: 579  total_loss: 0.634  loss_cls: 0.333  loss_box_reg: 0.309  time: 0.2002  data_time: 0.0050  lr: 0.000145  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:50  iter: 599  total_loss: 0.634  loss_cls: 0.341  loss_box_reg: 0.278  time: 0.2004  data_time: 0.0050  lr: 0.000150  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:46  iter: 619  total_loss: 0.702  loss_cls: 0.369  loss_box_reg: 0.316  time: 0.2005  data_time: 0.0050  lr: 0.000155  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:43  iter: 639  total_loss: 0.576  loss_cls: 0.322  loss_box_reg: 0.248  time: 0.2005  data_time: 0.0059  lr: 0.000160  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:39  iter: 659  total_loss: 0.574  loss_cls: 0.317  loss_box_reg: 0.264  time: 0.2005  data_time: 0.0048  lr: 0.000165  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:34  iter: 679  total_loss: 0.656  loss_cls: 0.372  loss_box_reg: 0.288  time: 0.2006  data_time: 0.0048  lr: 0.000170  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:31  iter: 699  total_loss: 0.643  loss_cls: 0.351  loss_box_reg: 0.283  time: 0.2007  data_time: 0.0051  lr: 0.000175  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:27  iter: 719  total_loss: 0.586  loss_cls: 0.313  loss_box_reg: 0.245  time: 0.2006  data_time: 0.0046  lr: 0.000180  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:23  iter: 739  total_loss: 0.612  loss_cls: 0.314  loss_box_reg: 0.286  time: 0.2007  data_time: 0.0051  lr: 0.000185  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:20  iter: 759  total_loss: 0.608  loss_cls: 0.329  loss_box_reg: 0.289  time: 0.2007  data_time: 0.0048  lr: 0.000190  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:16  iter: 779  total_loss: 0.664  loss_cls: 0.362  loss_box_reg: 0.298  time: 0.2008  data_time: 0.0052  lr: 0.000195  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:12  iter: 799  total_loss: 0.640  loss_cls: 0.340  loss_box_reg: 0.298  time: 0.2008  data_time: 0.0060  lr: 0.000200  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:08  iter: 819  total_loss: 0.588  loss_cls: 0.322  loss_box_reg: 0.271  time: 0.2008  data_time: 0.0052  lr: 0.000205  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:04  iter: 839  total_loss: 0.628  loss_cls: 0.327  loss_box_reg: 0.291  time: 0.2009  data_time: 0.0049  lr: 0.000210  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:07:00  iter: 859  total_loss: 0.558  loss_cls: 0.311  loss_box_reg: 0.257  time: 0.2008  data_time: 0.0059  lr: 0.000215  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:56  iter: 879  total_loss: 0.653  loss_cls: 0.354  loss_box_reg: 0.316  time: 0.2008  data_time: 0.0064  lr: 0.000220  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:53  iter: 899  total_loss: 0.602  loss_cls: 0.317  loss_box_reg: 0.266  time: 0.2012  data_time: 0.0061  lr: 0.000225  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:49  iter: 919  total_loss: 0.587  loss_cls: 0.334  loss_box_reg: 0.260  time: 0.2012  data_time: 0.0051  lr: 0.000230  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:45  iter: 939  total_loss: 0.593  loss_cls: 0.298  loss_box_reg: 0.248  time: 0.2013  data_time: 0.0053  lr: 0.000235  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:41  iter: 959  total_loss: 0.564  loss_cls: 0.303  loss_box_reg: 0.262  time: 0.2014  data_time: 0.0049  lr: 0.000240  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:37  iter: 979  total_loss: 0.631  loss_cls: 0.360  loss_box_reg: 0.284  time: 0.2015  data_time: 0.0051  lr: 0.000245  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:33  iter: 999  total_loss: 0.588  loss_cls: 0.333  loss_box_reg: 0.267  time: 0.2015  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:29  iter: 1019  total_loss: 0.601  loss_cls: 0.315  loss_box_reg: 0.296  time: 0.2016  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:25  iter: 1039  total_loss: 0.539  loss_cls: 0.299  loss_box_reg: 0.253  time: 0.2017  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:22  iter: 1059  total_loss: 0.622  loss_cls: 0.345  loss_box_reg: 0.269  time: 0.2017  data_time: 0.0058  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:18  iter: 1079  total_loss: 0.527  loss_cls: 0.279  loss_box_reg: 0.264  time: 0.2017  data_time: 0.0062  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:14  iter: 1099  total_loss: 0.646  loss_cls: 0.364  loss_box_reg: 0.276  time: 0.2016  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:11  iter: 1119  total_loss: 0.512  loss_cls: 0.293  loss_box_reg: 0.241  time: 0.2016  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:07  iter: 1139  total_loss: 0.600  loss_cls: 0.324  loss_box_reg: 0.269  time: 0.2017  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:06:04  iter: 1159  total_loss: 0.570  loss_cls: 0.303  loss_box_reg: 0.272  time: 0.2018  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:59  iter: 1179  total_loss: 0.546  loss_cls: 0.307  loss_box_reg: 0.233  time: 0.2017  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:56  iter: 1199  total_loss: 0.567  loss_cls: 0.310  loss_box_reg: 0.251  time: 0.2017  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:52  iter: 1219  total_loss: 0.530  loss_cls: 0.287  loss_box_reg: 0.247  time: 0.2019  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:48  iter: 1239  total_loss: 0.587  loss_cls: 0.325  loss_box_reg: 0.274  time: 0.2020  data_time: 0.0060  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:44  iter: 1259  total_loss: 0.513  loss_cls: 0.254  loss_box_reg: 0.250  time: 0.2022  data_time: 0.0058  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:40  iter: 1279  total_loss: 0.564  loss_cls: 0.323  loss_box_reg: 0.262  time: 0.2020  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:36  iter: 1299  total_loss: 0.535  loss_cls: 0.274  loss_box_reg: 0.255  time: 0.2019  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:32  iter: 1319  total_loss: 0.601  loss_cls: 0.292  loss_box_reg: 0.302  time: 0.2019  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:29  iter: 1339  total_loss: 0.519  loss_cls: 0.277  loss_box_reg: 0.249  time: 0.2021  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:25  iter: 1359  total_loss: 0.527  loss_cls: 0.291  loss_box_reg: 0.246  time: 0.2021  data_time: 0.0057  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:21  iter: 1379  total_loss: 0.476  loss_cls: 0.265  loss_box_reg: 0.222  time: 0.2023  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:17  iter: 1399  total_loss: 0.615  loss_cls: 0.342  loss_box_reg: 0.258  time: 0.2023  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:13  iter: 1419  total_loss: 0.528  loss_cls: 0.297  loss_box_reg: 0.255  time: 0.2023  data_time: 0.0058  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:09  iter: 1439  total_loss: 0.504  loss_cls: 0.257  loss_box_reg: 0.227  time: 0.2022  data_time: 0.0063  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:05  iter: 1459  total_loss: 0.556  loss_cls: 0.284  loss_box_reg: 0.280  time: 0.2022  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:05:01  iter: 1479  total_loss: 0.554  loss_cls: 0.283  loss_box_reg: 0.259  time: 0.2022  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:57  iter: 1499  total_loss: 0.550  loss_cls: 0.295  loss_box_reg: 0.258  time: 0.2023  data_time: 0.0057  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:53  iter: 1519  total_loss: 0.654  loss_cls: 0.335  loss_box_reg: 0.274  time: 0.2024  data_time: 0.0062  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:49  iter: 1539  total_loss: 0.582  loss_cls: 0.296  loss_box_reg: 0.259  time: 0.2024  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:46  iter: 1559  total_loss: 0.536  loss_cls: 0.266  loss_box_reg: 0.262  time: 0.2026  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:42  iter: 1579  total_loss: 0.521  loss_cls: 0.282  loss_box_reg: 0.268  time: 0.2027  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:38  iter: 1599  total_loss: 0.589  loss_cls: 0.326  loss_box_reg: 0.262  time: 0.2027  data_time: 0.0055  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:34  iter: 1619  total_loss: 0.524  loss_cls: 0.277  loss_box_reg: 0.244  time: 0.2027  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:30  iter: 1639  total_loss: 0.488  loss_cls: 0.281  loss_box_reg: 0.202  time: 0.2028  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:26  iter: 1659  total_loss: 0.532  loss_cls: 0.282  loss_box_reg: 0.252  time: 0.2029  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:22  iter: 1679  total_loss: 0.558  loss_cls: 0.278  loss_box_reg: 0.255  time: 0.2030  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:18  iter: 1699  total_loss: 0.454  loss_cls: 0.243  loss_box_reg: 0.215  time: 0.2030  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:15  iter: 1719  total_loss: 0.491  loss_cls: 0.266  loss_box_reg: 0.219  time: 0.2031  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:11  iter: 1739  total_loss: 0.550  loss_cls: 0.305  loss_box_reg: 0.256  time: 0.2030  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:07  iter: 1759  total_loss: 0.536  loss_cls: 0.312  loss_box_reg: 0.216  time: 0.2031  data_time: 0.0062  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:04:03  iter: 1779  total_loss: 0.564  loss_cls: 0.312  loss_box_reg: 0.251  time: 0.2030  data_time: 0.0059  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:59  iter: 1799  total_loss: 0.507  loss_cls: 0.291  loss_box_reg: 0.237  time: 0.2031  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:55  iter: 1819  total_loss: 0.507  loss_cls: 0.276  loss_box_reg: 0.216  time: 0.2031  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:51  iter: 1839  total_loss: 0.483  loss_cls: 0.269  loss_box_reg: 0.213  time: 0.2031  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:48  iter: 1859  total_loss: 0.454  loss_cls: 0.232  loss_box_reg: 0.220  time: 0.2032  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:45  iter: 1879  total_loss: 0.509  loss_cls: 0.283  loss_box_reg: 0.221  time: 0.2033  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:41  iter: 1899  total_loss: 0.463  loss_cls: 0.242  loss_box_reg: 0.218  time: 0.2033  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:37  iter: 1919  total_loss: 0.502  loss_cls: 0.278  loss_box_reg: 0.225  time: 0.2033  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:33  iter: 1939  total_loss: 0.535  loss_cls: 0.303  loss_box_reg: 0.242  time: 0.2033  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:29  iter: 1959  total_loss: 0.491  loss_cls: 0.275  loss_box_reg: 0.216  time: 0.2034  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:25  iter: 1979  total_loss: 0.505  loss_cls: 0.277  loss_box_reg: 0.236  time: 0.2035  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:21  iter: 1999  total_loss: 0.484  loss_cls: 0.267  loss_box_reg: 0.233  time: 0.2035  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:16  iter: 2019  total_loss: 0.544  loss_cls: 0.295  loss_box_reg: 0.248  time: 0.2035  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:12  iter: 2039  total_loss: 0.547  loss_cls: 0.322  loss_box_reg: 0.277  time: 0.2035  data_time: 0.0060  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:09  iter: 2059  total_loss: 0.545  loss_cls: 0.306  loss_box_reg: 0.282  time: 0.2036  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:05  iter: 2079  total_loss: 0.481  loss_cls: 0.261  loss_box_reg: 0.209  time: 0.2036  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:03:00  iter: 2099  total_loss: 0.443  loss_cls: 0.243  loss_box_reg: 0.200  time: 0.2036  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:56  iter: 2119  total_loss: 0.515  loss_cls: 0.252  loss_box_reg: 0.222  time: 0.2036  data_time: 0.0060  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:52  iter: 2139  total_loss: 0.580  loss_cls: 0.285  loss_box_reg: 0.282  time: 0.2037  data_time: 0.0058  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:49  iter: 2159  total_loss: 0.519  loss_cls: 0.281  loss_box_reg: 0.263  time: 0.2038  data_time: 0.0057  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:45  iter: 2179  total_loss: 0.479  loss_cls: 0.273  loss_box_reg: 0.241  time: 0.2038  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:41  iter: 2199  total_loss: 0.494  loss_cls: 0.262  loss_box_reg: 0.249  time: 0.2039  data_time: 0.0043  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:37  iter: 2219  total_loss: 0.470  loss_cls: 0.225  loss_box_reg: 0.246  time: 0.2040  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:33  iter: 2239  total_loss: 0.517  loss_cls: 0.277  loss_box_reg: 0.236  time: 0.2040  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:29  iter: 2259  total_loss: 0.426  loss_cls: 0.219  loss_box_reg: 0.220  time: 0.2040  data_time: 0.0057  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:25  iter: 2279  total_loss: 0.459  loss_cls: 0.253  loss_box_reg: 0.212  time: 0.2040  data_time: 0.0047  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:21  iter: 2299  total_loss: 0.470  loss_cls: 0.269  loss_box_reg: 0.188  time: 0.2040  data_time: 0.0059  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:17  iter: 2319  total_loss: 0.389  loss_cls: 0.221  loss_box_reg: 0.191  time: 0.2041  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:13  iter: 2339  total_loss: 0.526  loss_cls: 0.262  loss_box_reg: 0.252  time: 0.2041  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:09  iter: 2359  total_loss: 0.526  loss_cls: 0.289  loss_box_reg: 0.232  time: 0.2041  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:05  iter: 2379  total_loss: 0.488  loss_cls: 0.252  loss_box_reg: 0.227  time: 0.2041  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:02:01  iter: 2399  total_loss: 0.503  loss_cls: 0.276  loss_box_reg: 0.231  time: 0.2042  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:57  iter: 2419  total_loss: 0.431  loss_cls: 0.235  loss_box_reg: 0.194  time: 0.2042  data_time: 0.0046  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:53  iter: 2439  total_loss: 0.491  loss_cls: 0.247  loss_box_reg: 0.238  time: 0.2042  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:49  iter: 2459  total_loss: 0.480  loss_cls: 0.252  loss_box_reg: 0.200  time: 0.2042  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:45  iter: 2479  total_loss: 0.451  loss_cls: 0.238  loss_box_reg: 0.234  time: 0.2042  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:41  iter: 2499  total_loss: 0.441  loss_cls: 0.226  loss_box_reg: 0.228  time: 0.2042  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:37  iter: 2519  total_loss: 0.493  loss_cls: 0.244  loss_box_reg: 0.237  time: 0.2042  data_time: 0.0054  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:33  iter: 2539  total_loss: 0.520  loss_cls: 0.267  loss_box_reg: 0.223  time: 0.2042  data_time: 0.0057  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:29  iter: 2559  total_loss: 0.515  loss_cls: 0.249  loss_box_reg: 0.235  time: 0.2043  data_time: 0.0058  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:24  iter: 2579  total_loss: 0.504  loss_cls: 0.260  loss_box_reg: 0.230  time: 0.2043  data_time: 0.0060  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:21  iter: 2599  total_loss: 0.449  loss_cls: 0.246  loss_box_reg: 0.204  time: 0.2043  data_time: 0.0061  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:17  iter: 2619  total_loss: 0.538  loss_cls: 0.286  loss_box_reg: 0.225  time: 0.2043  data_time: 0.0049  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:12  iter: 2639  total_loss: 0.489  loss_cls: 0.268  loss_box_reg: 0.204  time: 0.2043  data_time: 0.0048  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:08  iter: 2659  total_loss: 0.567  loss_cls: 0.301  loss_box_reg: 0.278  time: 0.2043  data_time: 0.0056  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:04  iter: 2679  total_loss: 0.434  loss_cls: 0.252  loss_box_reg: 0.203  time: 0.2043  data_time: 0.0047  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:01:00  iter: 2699  total_loss: 0.449  loss_cls: 0.250  loss_box_reg: 0.203  time: 0.2043  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:56  iter: 2719  total_loss: 0.420  loss_cls: 0.213  loss_box_reg: 0.190  time: 0.2044  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:52  iter: 2739  total_loss: 0.480  loss_cls: 0.291  loss_box_reg: 0.224  time: 0.2044  data_time: 0.0055  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:48  iter: 2759  total_loss: 0.470  loss_cls: 0.257  loss_box_reg: 0.214  time: 0.2045  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:44  iter: 2779  total_loss: 0.444  loss_cls: 0.244  loss_box_reg: 0.212  time: 0.2045  data_time: 0.0057  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:40  iter: 2799  total_loss: 0.437  loss_cls: 0.215  loss_box_reg: 0.204  time: 0.2046  data_time: 0.0052  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:36  iter: 2819  total_loss: 0.453  loss_cls: 0.242  loss_box_reg: 0.228  time: 0.2046  data_time: 0.0050  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:32  iter: 2839  total_loss: 0.398  loss_cls: 0.233  loss_box_reg: 0.176  time: 0.2045  data_time: 0.0049  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:28  iter: 2859  total_loss: 0.470  loss_cls: 0.262  loss_box_reg: 0.210  time: 0.2046  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:24  iter: 2879  total_loss: 0.454  loss_cls: 0.223  loss_box_reg: 0.228  time: 0.2046  data_time: 0.0051  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:20  iter: 2899  total_loss: 0.427  loss_cls: 0.220  loss_box_reg: 0.202  time: 0.2046  data_time: 0.0047  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:16  iter: 2919  total_loss: 0.469  loss_cls: 0.248  loss_box_reg: 0.222  time: 0.2046  data_time: 0.0047  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:12  iter: 2939  total_loss: 0.425  loss_cls: 0.230  loss_box_reg: 0.204  time: 0.2046  data_time: 0.0055  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:08  iter: 2959  total_loss: 0.475  loss_cls: 0.249  loss_box_reg: 0.227  time: 0.2047  data_time: 0.0063  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.utils.events:eta: 0:00:04  iter: 2979  total_loss: 0.502  loss_cls: 0.244  loss_box_reg: 0.235  time: 0.2047  data_time: 0.0060  lr: 0.000250  max_mem: 3170M
# INFO:fvcore.common.checkpoint:Saving checkpoint to ./output/model_final.pth
# INFO:detectron2.utils.events:eta: 0:00:00  iter: 2999  total_loss: 0.391  loss_cls: 0.210  loss_box_reg: 0.190  time: 0.2047  data_time: 0.0053  lr: 0.000250  max_mem: 3170M
# INFO:detectron2.engine.hooks:Overall training speed: 2997 iterations in 0:10:13 (0.2048 s / it)
# INFO:detectron2.engine.hooks:Total training time: 0:10:21 (0:00:07 on hooks)
# OrderedDict()

# %%
# from detectron2.engine import DefaultTrainer
# from detectron2.config import get_cfg

# cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/retinanet_R_101_FPN_3x.yaml"))
# cfg.DATASETS.TRAIN = ("balloon_train",)
# cfg.DATASETS.TEST = ("balloon_val",)
# cfg.DATALOADER.NUM_WORKERS = 2
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/retinanet_R_101_FPN_3x.yaml")  # Let training initialize from model zoo
# cfg.SOLVER.IMS_PER_BATCH = 2
# cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
# cfg.SOLVER.MAX_ITER = 300    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
# cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset (default: 512)
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ballon)

# os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
# trainer = DefaultTrainer(cfg) 
# trainer.resume_or_load(resume=False)
# trainer.train()

# %%
#https://detectron2.readthedocs.io/_modules/detectron2/modeling/meta_arch/retinanet.html

# Predict
# cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/retinanet_R_101_FPN_3x.yaml"))
# cfg.DATASETS.TRAIN = ("balloon_train",)
# cfg.DATASETS.TEST = ("balloon_val",)
# cfg.DATALOADER.NUM_WORKERS = 2
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/retinanet_R_101_FPN_3x.yaml")  # Let training initialize from model zoo
# cfg.SOLVER.IMS_PER_BATCH = 2
# cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
# cfg.SOLVER.MAX_ITER = 300    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
# cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset (default: 512)
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ballon)




cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
print(cfg.MODEL.WEIGHTS)
###cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.99   # set the testing threshold for this model
cfg.MODEL.RETINANET.SCORE_THRESH_TEST =0.4  # set threshold for retinanet
cfg.MODEL.RETINANET.NMS_THRESH_TEST =0.1
#cfg.TEST.DETECTIONS_PER_IMAGE = 2
cfg.DATASETS.TEST = ("lung_val", )
predictor = DefaultPredictor(cfg)


import pydevd_pycharm

#pydevd_pycharm.settrace('192.168.1.100', port=1234, stdoutToServer=True, stderrToServer=True)

from detectron2.utils.visualizer import ColorMode
dataset_dicts = get_anotation_dicts((4,) )
#dataset_dicts = get_anotation_dicts((4,) , box_cnt=1)

img_list= []
random.seed(666)
for d in random.sample(dataset_dicts, min(8, len(dataset_dicts))):   
    #Predict Result
    im = cv2.imread(d["file_name"])
    file_list.append(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],  metadata=metadata,  scale=0.2, 
                   #instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu")) 
    img_list.append(v.get_image()[:, :, ::-1])
    print(d["file_name"])
    
    #Ground Truth
    visualizer = Visualizer(im[:, :, ::-1], metadata=metadata, scale=0.2)
    vis = visualizer.draw_dataset_dict(d)
    img_list.append(vis.get_image()[:, :, ::-1])

    
fig = plt.figure(figsize=(20., 50.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4,4),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 share_all=True,
                 )

for ax, im in zip(grid, img_list):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)
plt.show()
# Out:
# ./output/model_final.pth
# INFO:fvcore.common.checkpoint:Loading checkpoint from ./output/model_final.pth
# input/train/10569.jpg
# input/train/8659.jpg
# input/train/10154.jpg
# input/train/6669.jpg
# input/train/11769.jpg
# input/train/349.jpg
# input/train/18974.jpg
# input/train/12754.jpg
