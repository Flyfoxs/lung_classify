# %%
import os

def adjust_wkdir(cut_folder='notebook'):
    abspath = os.path.abspath('.')
    wk_dir = abspath.replace(cut_folder,'')
    os.chdir(wk_dir)
    return wk_dir


adjust_wkdir()
# Out:
# '/share/felix/pj/lung_classify/'

# %%
import pandas as pd
import os
from task_distribute.locker import task_locker
from file_cache.cache import file_cache, logger, timed

#from tqdm._tqdm_notebook import tqdm_notebook as  tqdm

from tqdm import tqdm, tqdm_notebook
from glob import glob
import itertools
import numpy as np
from easydict import EasyDict as edict

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# 2020-02-08 21:10:45,877 util_log.py[138] INFO Start the program at:amax7, 127.0.1.1, with:Load module
# yes

# %%
import os
import nibabel as nib

data = nib.load('./sample/case_00023/imaging.nii.gz')
print(data.shape)
# Out:
# (107, 512, 512)

# %%
# !ls sample
# Out:
# case_00023

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(data.get_data()[50,:,:])
# Out:
# 2020-02-08 21:12:33,613 pyplot.py[225] DEBUG Loaded backend module://ipykernel.pylab.backend_inline version unknown.
